# %%
# !wget https://1.bp.blogspot.com/-LpMUFoLcMhQ/VrMB70ZJkbI/AAAAAAAAG8I/PyIfIkezct4/s1600/Poster%2BHijaiyah%2BCurve%2BA3.png
# Out:
# --2021-08-28 02:19:39--  https://1.bp.blogspot.com/-LpMUFoLcMhQ/VrMB70ZJkbI/AAAAAAAAG8I/PyIfIkezct4/s1600/Poster%2BHijaiyah%2BCurve%2BA3.png
# Resolving 1.bp.blogspot.com (1.bp.blogspot.com)... 108.177.127.132, 2a00:1450:4013:c07::84
# Connecting to 1.bp.blogspot.com (1.bp.blogspot.com)|108.177.127.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 269292 (263K) [image/png]
# Saving to: ‘Poster+Hijaiyah+Curve+A3.png’
#
# Poster+Hijaiyah+Cur 100%[===================>] 262.98K  --.-KB/s    in 0.002s
#
# 2021-08-28 02:19:39 (114 MB/s) - ‘Poster+Hijaiyah+Curve+A3.png’ saved [269292/269292]

# %%
from IPython.display import Image
Image('/content/Poster+Hijaiyah+Curve+A3.png')

# %% [markdown]
# convert to bmp

# %%
from PIL import Image
Image.open("/content/Poster+Hijaiyah+Curve+A3.png").save("sample1.bmp")

# %% [markdown]
# convert from bmp to png

# %%
from PIL import Image
Image.open("/content/sample1.bmp").save("sample1.png")

# %% [markdown]
# convert bmp to jpg

# %%
from PIL import Image
Image.open("/content/sample1.bmp").save("sample1.jpg")
